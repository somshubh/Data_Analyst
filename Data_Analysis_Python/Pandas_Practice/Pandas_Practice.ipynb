# %%
import pandas as pd
raw_data = pd.read_csv('Lending-company-csv.csv')
company_data = raw_data.copy()
company_data.head(10)
# Out:
#    Loan ID String_ID    Product CustomerGender     Location    Region  \
# 0        1      id_1  Product B           Male   Location 2  Region 2
# 1        2      id_2  Product B           Male   Location 3  Region 3
# 2        3      id_3  Product C         Female   Location 5  Region 5
# 3        4      id_4  Product B           Male   Location 6  Region 1
# 4        5      id_5  Product D         Female   Location 7  Region 2
# 5        6      id_6  Product B         Female  Location 10  Region 2
# 6        7      id_7  Product A           Male  Location 11  Region 3
# 7        8      id_8  Product B           Male  Location 12  Region 6
# 8        9      id_9  Product A         Female   Location 3  Region 3
# 9       10     id_10  Product A         Female  Location 13  Region 6
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDays  AmountPaid30  \
# 0       16600    7/4/2014     2000         40        365          3121
# ...

# %%
company_data.index
# Out:
# RangeIndex(start=0, stop=1043, step=1)

# %%
company_data.dtypes
# Out:
# Loan ID            int64
# String_ID         object
# Product           object
# CustomerGender    object
# Location          object
# Region            object
# TotalPrice         int64
# StartDate         object
# Deposit            int64
# DailyRate          int64
# TotalDays          int64
# AmountPaid30       int64
# AmountPaid60       int64
# AmountPaid360      int64
# LoanStatus360     object
# dtype: object

# %%
company_data.values
# Out:
# array([[1, 'id_1', 'Product B', ..., 4241, 13621, 'Active'],
#        [2, 'id_2', 'Product B', ..., 4171, 15041, 'Active'],
#        [3, 'id_3', 'Product C', ..., 3280, 15340, nan],
#        ...,
#        [1041, 'id_1041', 'Product B', ..., 5001, 16600,
#         'Finished Payment'],
#        [1042, 'id_1042', 'Product C', ..., 3320, 15600,
#         'Finished Payment'],
#        [1043, 'id_1043', 'Product B', ..., 4601, 16600,
#         'Finished Payment']], dtype=object)

# %%
type(company_data.values)
# Out:
# numpy.ndarray

# %%
company_data.to_numpy()
# Out:
# array([[1, 'id_1', 'Product B', ..., 4241, 13621, 'Active'],
#        [2, 'id_2', 'Product B', ..., 4171, 15041, 'Active'],
#        [3, 'id_3', 'Product C', ..., 3280, 15340, nan],
#        ...,
#        [1041, 'id_1041', 'Product B', ..., 5001, 16600,
#         'Finished Payment'],
#        [1042, 'id_1042', 'Product C', ..., 3320, 15600,
#         'Finished Payment'],
#        [1043, 'id_1043', 'Product B', ..., 4601, 16600,
#         'Finished Payment']], dtype=object)

# %%
type(company_data.to_numpy())
# Out:
# numpy.ndarray

# %%
company_data.columns
# Out:
# Index(['Loan ID', 'String_ID', 'Product', 'CustomerGender', 'Location',
#        'Region', 'TotalPrice', 'StartDate', 'Deposit', 'DailyRate',
#        'TotalDays', 'AmountPaid30', 'AmountPaid60', 'AmountPaid360',
#        'LoanStatus360'],
#       dtype='object')

# %%
company_data.axes
# Out:
# [RangeIndex(start=0, stop=1043, step=1),
#  Index(['Loan ID', 'String_ID', 'Product', 'CustomerGender', 'Location',
#         'Region', 'TotalPrice', 'StartDate', 'Deposit', 'DailyRate',
#         'TotalDays', 'AmountPaid30', 'AmountPaid60', 'AmountPaid360',
#         'LoanStatus360'],
#        dtype='object')]

# %%
company_data.index.name = 'Index'

# %%
company_data.index.name
# Out:
# 'Index'

# %%
company_data[['Loan ID', 'String_ID']][0:5]
# Out:
#        Loan ID String_ID
# Index
# 0            1      id_1
# 1            2      id_2
# 2            3      id_3
# 3            4      id_4
# 4            5      id_5

# %%
import pandas as pd
raw_data_1 = pd.read_csv('Lending-company-csv.csv', index_col='String_ID')
company_data_1 = raw_data_1.copy()
company_data_1.head(10)
# Out:
#            Loan ID    Product CustomerGender     Location    Region  \
# String_ID
# id_1             1  Product B           Male   Location 2  Region 2
# id_2             2  Product B           Male   Location 3  Region 3
# id_3             3  Product C         Female   Location 5  Region 5
# id_4             4  Product B           Male   Location 6  Region 1
# id_5             5  Product D         Female   Location 7  Region 2
# id_6             6  Product B         Female  Location 10  Region 2
# id_7             7  Product A           Male  Location 11  Region 3
# id_8             8  Product B           Male  Location 12  Region 6
# id_9             9  Product A         Female   Location 3  Region 3
# id_10           10  Product A         Female  Location 13  Region 6
#
#            TotalPrice   StartDate  Deposit  DailyRate  TotalDays  \
# String_ID
# id_1            16600    7/4/2014     2000         40        365
# ...

# %%
company_data_1.iloc[2,3]
# Out:
# 'Location 5'

# %%
company_data_1.iloc[2,:]
# Out:
# Loan ID                    3
# Product            Product C
# CustomerGender        Female
# Location          Location 5
# Region              Region 5
# TotalPrice             15600
# StartDate          12/8/2012
# Deposit                 1000
# DailyRate                 40
# TotalDays                365
# AmountPaid30            2160
# AmountPaid60            3280
# AmountPaid360          15340
# LoanStatus360            NaN
# Name: id_3, dtype: object

# %%
company_data_1.iloc[: ,2]
# Out:
# String_ID
# id_1               Male
# id_2               Male
# id_3             Female
# id_4               Male
# id_5             Female
#                ...
# id_1039          Female
# id_1040            Male
# id_1041            Male
# id_1042    NotSpecified
# id_1043          Female
# Name: CustomerGender, Length: 1043, dtype: object

# %%
company_data_1.iloc[[1 ,2, 4],:]
# Out:
#            Loan ID    Product CustomerGender    Location    Region  \
# String_ID
# id_2             2  Product B           Male  Location 3  Region 3
# id_3             3  Product C         Female  Location 5  Region 5
# id_5             5  Product D         Female  Location 7  Region 2
#
#            TotalPrice   StartDate  Deposit  DailyRate  TotalDays  \
# String_ID
# id_2            16600    1/2/2015     2000         40        365
# id_3            15600   12/8/2012     1000         40        365
# id_5            20250  10/28/2013     2000         50        365
#
#            AmountPaid30  AmountPaid60  AmountPaid360 LoanStatus360
# String_ID
# id_2               3061          4171          15041        Active
# id_3               2160          3280          15340           NaN
# id_5               3470          4820          13720        Active

# %%
company_data_1.loc['id_3', 'Region']
# Out:
# 'Region 5'

# %%
company_data_1.loc[ :, ['Region', 'Location']]
# Out:
#              Region      Location
# String_ID
# id_1       Region 2    Location 2
# id_2       Region 3    Location 3
# id_3       Region 5    Location 5
# id_4       Region 1    Location 6
# id_5       Region 2    Location 7
# ...             ...           ...
# id_1039    Region 6   Location 39
# id_1040    Region 1   Location 50
# id_1041    Region 4   Location 23
# id_1042    Region 6   Location 52
# id_1043    Region 6  Location 142
#
# [1043 rows x 2 columns]

# %%
company_data_1.head(10)
# Out:
#            Loan ID    Product CustomerGender     Location    Region  \
# String_ID
# id_1             1  Product B           Male   Location 2  Region 2
# id_2             2  Product B           Male   Location 3  Region 3
# id_3             3  Product C         Female   Location 5  Region 5
# id_4             4  Product B           Male   Location 6  Region 1
# id_5             5  Product D         Female   Location 7  Region 2
# id_6             6  Product B         Female  Location 10  Region 2
# id_7             7  Product A           Male  Location 11  Region 3
# id_8             8  Product B           Male  Location 12  Region 6
# id_9             9  Product A         Female   Location 3  Region 3
# id_10           10  Product A         Female  Location 13  Region 6
#
#            TotalPrice   StartDate  Deposit  DailyRate  TotalDays  \
# String_ID
# id_1            16600    7/4/2014     2000         40        365
# ...

# %%
company_data_1['Location'].iloc[3]
# Out:
# 'Location 6'

# %%
type(company_data_1)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd
raw_data_2 = pd.read_csv('Lending-company-csv.csv', index_col='Loan ID')
company_data_2 = raw_data_2.copy()
company_data_2.head(10)
# Out:
#         String_ID    Product CustomerGender     Location    Region  \
# Loan ID
# 1            id_1  Product B           Male   Location 2  Region 2
# 2            id_2  Product B           Male   Location 3  Region 3
# 3            id_3  Product C         Female   Location 5  Region 5
# 4            id_4  Product B           Male   Location 6  Region 1
# 5            id_5  Product D         Female   Location 7  Region 2
# 6            id_6  Product B         Female  Location 10  Region 2
# 7            id_7  Product A           Male  Location 11  Region 3
# 8            id_8  Product B           Male  Location 12  Region 6
# 9            id_9  Product A         Female   Location 3  Region 3
# 10          id_10  Product A         Female  Location 13  Region 6
#
#          TotalPrice   StartDate  Deposit  DailyRate  TotalDays  AmountPaid30  \
# Loan ID
# 1             16600    7/4/2014     2000         40        365          3121
# ...

# %%
company_data_2['TotalPrice'][2]
# Out:
# 16600

# %%
company_data_1['TotalPrice'][2]
# Out:
# /tmp/ipykernel_942/4233132632.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   company_data_1['TotalPrice'][2]
# 15600

# %%
company_data_1.head(10)
# Out:
#            Loan ID    Product CustomerGender     Location    Region  \
# String_ID
# id_1             1  Product B           Male   Location 2  Region 2
# id_2             2  Product B           Male   Location 3  Region 3
# id_3             3  Product C         Female   Location 5  Region 5
# id_4             4  Product B           Male   Location 6  Region 1
# id_5             5  Product D         Female   Location 7  Region 2
# id_6             6  Product B         Female  Location 10  Region 2
# id_7             7  Product A           Male  Location 11  Region 3
# id_8             8  Product B           Male  Location 12  Region 6
# id_9             9  Product A         Female   Location 3  Region 3
# id_10           10  Product A         Female  Location 13  Region 6
#
#            TotalPrice   StartDate  Deposit  DailyRate  TotalDays  \
# String_ID
# id_1            16600    7/4/2014     2000         40        365
# ...

# %%
company_data_1.index.name
# Out:
# 'String_ID'

# %%
import pandas as pd
raw_data_2 = pd.read_csv('Lending-company-csv.csv', index_col='Loan ID', usecols = ['Loan ID', 'Location'])
Series_company_data_2 = raw_data_2.squeeze('columns')
Series_company_data_2
# Out:
# Loan ID
# 1         Location 2
# 2         Location 3
# 3         Location 5
# 4         Location 6
# 5         Location 7
#             ...
# 1039     Location 39
# 1040     Location 50
# 1041     Location 23
# 1042     Location 52
# 1043    Location 142
# Name: Location, Length: 1043, dtype: object

# %%
Series_company_data_2.nunique()
# Out:
# 296
